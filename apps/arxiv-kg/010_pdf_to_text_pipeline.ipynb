# %% [markdown]
# # knowledge graph index pdf pipeline

# %%
import os
import time

import openai
os.environ['OPENAI_API_KEY'] = "EMPTY"
os.environ['OPENAI_API_BASE'] = "http://10.0.0.222:30307/v1"
openai.api_key = "EMPTY"
openai.api_base = "http://10.0.0.222:30307/v1"

model = "Writer/camel-5b-hf"
#model = "mosaicml/mpt-7b-instruct"
#model = "mosaicml/mpt-30b-instruct"

# %%
import logging
import sys

#kron extensions to llama_index to support openai compatible api
#sys.path.append('../llama_index')

logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
#CORPUS = 'ArxivHealthcareNLP'
CORPUS = 'arxiv_cl'

# %%
def load_properties(filepath, sep='=', comment_char='#'):
    '''
    Read the file passed as parameter as a properties file.
    '''
    props = {}
    with open(filepath, "rt") as f:
        for line in f:
            l = line.strip()
            if l and not l.startswith(comment_char):
                key_value = l.split(sep)
                key = key_value[0].strip()
                value = sep.join(key_value[1:]).strip().strip('"') 
                props[key] = value 
    return props

corpus_properties = load_properties(f"corpora/{CORPUS}.properties")
corpus_properties

# %%
from datetime import datetime
import json
import pathlib
import fitz

CORPUS_BASE = '/home/arylwen/datasets/documents/ArxivHealthcareNLP'
PDF_BASE = f'{CORPUS_BASE}/pdf/'
JSON_BASE = f'{CORPUS_BASE}/json_raw/'

JSON_BASE
# Out:
# '/home/arylwen/datasets/documents/ArxivHealthcareNLP/json_raw/'

# %%
from os import listdir
from os.path import isfile, join
pdf_files = [f for f in listdir(PDF_BASE) if isfile(join(PDF_BASE, f))]
pdf_files
# Out:
# ['2211.01705v1.A_speech_corpus_for_chronic_kidney_disease.pdf',
#  '2211.01761v1.PromptEHR__Conditional_Electronic_Healthcare_Records_Generation_with_Prompt_Learning.pdf',
#  '2211.03536v1.Knowledge_Graph_Embedding__A_Survey_from_the_Perspective_of_Representation_Spaces.pdf',
#  '2211.03818v1.CELLS__A_Parallel_Corpus_for_Biomedical_Lay_Language_Generation.pdf',
#  '2211.04013v1.COV19IR___COVID_19_Domain_Literature_Information_Retrieval.pdf',
#  '2211.04569v1.Toward_a_Neural_Semantic_Parsing_System_for_EHR_Question_Answering.pdf',
#  '2211.04759v1.Nested_Named_Entity_Recognition_from_Medical_Texts__An_Adaptive_Shared_Network_Architecture_with_Attentive_CRF.pdf',
#  '2211.06778v1.Textual_Data_Augmentation_for_Patient_Outcomes_Prediction.pdf',
#  '2211.07047v2.Language_Model_Classifier_Aligns_Better_with_Physician_Word_Sensitivity_than_XGBoost_on_Readmission_Prediction.pdf',
#  '2211.07126v3.Discharge_Summary_Hospital_Course_Summarisation_of_In_Patient_Electronic_Health_Record_Text_with_Clinical_Concept_Guided_Deep_Pre_Trained_Transformer_Models.pdf',
#  '2211.07465v1.Findings_of_the_Covid_19_MLIA_Machine_Translation_Task.pdf',
#  '2211.07703v1.Alzheimer_s_Diagnosis_and_Generation_Based_Chatbot_Using_Hierarchical_Attention_and_Transformer.pdf',
#  '2211.07713v1.How_Long_Is_Enough__Exploring_the_Optimal_Intervals_of_Long_Range_Clinical_Note_Language_Modeling.pdf',
#  '2211.08732v2.Lesion_Guided_Explainable_Few_Weak_shot_Medical_Report_Generation.pdf',
#  '2211.08742v1.Auditing_Algorithmic_Fairness_in_Machine_Learning_for_Health_with_Severity_Based_LOGAN.pdf',
#  '2211.09085v1.Galactica__A_Large_Language_Model_for_Science.pdf',
#  '2211.09455v1.Consultation_Checklists__Standardising_the_Human_Evaluation_of_Medical_Note_Generation.pdf',
#  '2211.09722v1.Federated_Multilingual_Models_for_Medical_Transcript_Analysis.pdf',
#  '2211.10265v3.Context_Variance_Evaluation_of_Pretrained_Language_Models_for_Prompt_based_Biomedical_Knowledge_Probing.pdf',
#  '2211.11363v1.CBEAF_Adapting__Enhanced_Continual_Pretraining_for_Building_Chinese_Biomedical_Language_Model.pdf',
#  '2211.12124v1.A_Large_Scale_Dataset_for_Biomedical_Keyphrase_Generation.pdf',
#  '2211.12360v1.GDPR_Compliant_Collection_of_Therapist_Patient_Dialogues.pdf',
#  '2211.12737v1.RoentGen__Vision_Language_Foundation_Model_for_Chest_X_ray_Generation.pdf',
#  '2211.13229v1.DeltaNet_Conditional_Medical_Report_Generation_for_COVID_19_Diagnosis.pdf',
#  '2211.13308v2.SciRepEval__A_Multi_Format_Benchmark_for_Scientific_Document_Representations.pdf',
#  '2211.13813v2.Multi_label_Few_shot_ICD_Coding_as_Autoregressive_Generation_with_Prompt.pdf',
#  '2211.14372v1.Interpretability_Analysis_of_Deep_Models_for_COVID_19_Detection.pdf',
#  '2211.15022v1.Summer__WeChat_Neural_Machine_Translation_Systems_for_the_WMT22_Biomedical_Translation_Task.pdf',
#  '2211.15268v1.Scientific_and_Creative_Analogies_in_Pretrained_Language_Models.pdf',
#  '2211.15328v1.A_Survey_on_Conversational_Search_and_Applications_in_Biomedicine.pdf',
#  '2211.16944v3.AIONER__All_in_one_scheme_based_biomedical_named_entity_recognition_using_deep_learning.pdf',
#  '2211.17121v1.sEHR_CE__Language_modelling_of_structured_EHR_data_for_efficient_and_generalizable_patient_cohort_expansion.pdf',
#  '2212.00223v1.Biomedical_NER_for_the_Enterprise_with_Distillated_BERN2_and_the_Kazu_Framework.pdf',
#  '2212.00689v1.CliMedBERT__A_Pre_trained_Language_Model_for_Climate_and_Health_related_Text.pdf',
#  '2212.01217v1.Using_Large_Pre_Trained_Language_Model_to_Assist_FDA_in_Premarket_Medical_Device.pdf',
#  '2212.01462v1.Topic_Modeling_on_Clinical_Social_Work_Notes_for_Exploring_Social_Determinants_of_Health_Factors.pdf',
#  '2212.01552v1.Meta_Learning_for_Few_Shot_Medical_Text_Classification.pdf',
#  '2212.01669v1.A_Survey_on_Medical_Document_Summarization.pdf',
#  '2212.03000v2.SODA__A_Natural_Language_Processing_Package_to_Extract_Social_Determinants_of_Health_for_Cancer_Studies.pdf',
#  '2212.05039v1.Incorporating_Emotions_into_Health_Mention_Classification_Task_on_Social_Media.pdf',
#  '2212.05857v2.Automated_ICD_Coding_using_Extreme_Multi_label_Long_Text_Transformer_based_Models.pdf',
#  '2212.06267v1.Mortality_Prediction_Models_with_Clinical_Notes_Using_Sparse_Attention_at_the_Word_and_Sentence_Levels.pdf',
#  '2212.07507v1.Artificial_Intelligence_for_Health_Message_Generation__Theory__Method__and_an_Empirical_Study_Using_Prompt_Engineering.pdf',
#  '2212.09867v1.Detecting_Contradictory_COVID_19_Drug_Efficacy_Claims_from_Biomedical_Literature.pdf',
#  '2212.10714v1.Integrating_Heterogeneous_Domain_Information_into_Relation_Extraction__A_Case_Study_on_Drug_Drug_Interaction_Extraction.pdf',
#  '2212.13138v1.Large_Language_Models_Encode_Clinical_Knowledge.pdf',
#  '2212.13408v3.NEEDED__Introducing_Hierarchical_Transformer_to_Eye_Diseases_Diagnosis.pdf',
#  '2212.14102v1.Customizing_Knowledge_Graph_Embedding_to_Improve_Clinical_Study_Recommendation.pdf',
#  '2212.14882v1.ChatGPT_Makes_Medicine_Easy_to_Swallow__An_Exploratory_Case_Study_on_Simplified_Radiology_Reports.pdf',
#  '2301.02228v3.MedKLIP__Medical_Knowledge_Enhanced_Language_Image_Pre_Training_in_Radiology.pdf',
#  '2301.02589v2.Causal_Categorization_of_Mental_Health_Posts_using_Transformers.pdf',
#  '2301.03531v1.Leveraging_Contextual_Relatedness_to_Identify_Suicide_Documentation_in_Clinical_Notes_through_Zero_Shot_Learning.pdf',
#  '2301.05562v1.Multilingual_Alzheimer_s_Dementia_Recognition_through_Spontaneous_Speech__a_Signal_Processing_Grand_Challenge.pdf',
#  '2301.05571v2.The_2022_n2c2_UW_Shared_Task_on_Extracting_Social_Determinants_of_Health.pdf',
#  '2301.06340v2.Deep_Learning_Models_to_Study_Sentence_Comprehension_in_the_Human_Brain.pdf',
#  '2301.07695v4.EHRSQL__A_Practical_Text_to_SQL_Benchmark_for_Electronic_Health_Records.pdf',
#  '2301.09017v2.Transfer_Knowledge_from_Natural_Language_to_Electrocardiography__Can_We_Detect_Cardiovascular_Disease_Through_Language_Models_.pdf',
#  '2301.09237v1.Semantic_aware_Contrastive_Learning_for_Electroencephalography_to_Text_Generation_with_Curriculum_Learning.pdf',
#  '2301.09908v1.Cross_lingual_German_Biomedical_Information_Extraction__from_Zero_shot_to_Human_in_the_Loop.pdf',
#  '2301.10451v1.Knowledge_augmented_Graph_Neural_Networks_with_Concept_aware_Attention_for_Adverse_Drug_Event_Detection.pdf',
#  '2301.10527v1.Cross_lingual_Argument_Mining_in_the_Medical_Domain.pdf',
#  '2301.10951v1.Cross_Modal_Global_Local_Representation_Learning_from_Radiology_Reports_and_X_Ray_Chest_Images.pdf',
#  '2301.12473v1.Large_Language_Models_for_Biomedical_Causal_Graph_Construction.pdf',
#  '2301.13155v2.Advancing_Radiograph_Representation_Learning_with_Masked_Record_Modeling.pdf',
#  '2302.01588v1.Bioformer__an_efficient_transformer_language_model_for_biomedical_text_mining.pdf',
#  '2302.03822v2.Clinical_BioBERT_Hyperparameter_Optimization_using_Genetic_Algorithm.pdf',
#  '2302.04001v1.Leveraging_Summary_Guidance_on_Medical_Report_Summarization.pdf',
#  '2302.04185v1.Efficient_Joint_Learning_for_Clinical_Named_Entity_Recognition_and_Relation_Extraction_Using_Fourier_Networks__A_Use_Case_in_Adverse_Drug_Events.pdf',
#  '2302.08091v1.Do_We_Still_Need_Clinical_Language_Models_.pdf',
#  '2302.12343v1.CHiLL__Zero_shot_Custom_Interpretable_Feature_Extraction_from_Clinical_Notes_with_Large_Language_Models.pdf',
#  '2303.00915v1.Large_Scale_Domain_Specific_Pretraining_for_Biomedical_Vision_Language_Processing.pdf',
#  '2303.01229v2.Almanac__Retrieval_Augmented_Language_Models_for_Clinical_Medicine.pdf',
#  '2303.04360v2.Does_Synthetic_Data_Generation_of_LLMs_Help_Clinical_Text_Mining_.pdf',
#  '2303.05737v4.Clinical_BERTScore__An_Improved_Measure_of_Automatic_Speech_Recognition_Performance_in_Clinical_Settings.pdf',
#  '2303.06002v1.Is_In_hospital_Meta_information_Useful_for_Abstractive_Discharge_Summary_Generation_.pdf',
#  '2303.08038v1.Progress_Note_Understanding____Assessment_and_Plan_Reasoning__Overview_of_the_2022_N2C2_Track_3_Shared_Task.pdf',
#  '2303.08179v2.MEDBERT_de__A_Comprehensive_German_BERT_Model_for_the_Medical_Domain.pdf',
#  '2303.08259v1.Contextualized_Medication_Information_Extraction_Using_Transformer_based_Deep_Learning_Architectures.pdf',
#  '2303.08262v1.Clinical_Concept_and_Relation_Extraction_Using_Prompt_based_Machine_Reading_Comprehension.pdf',
#  '2303.08335v2.FactReranker__Fact_guided_Reranker_for_Faithful_Radiology_Report_Summarization.pdf',
#  '2303.09395v1.Text_to_ECG__12_Lead_Electrocardiogram_Synthesis_conditioned_on_Clinical_Text_Reports.pdf',
#  '2303.10330v3.Exploring_Partial_Knowledge_Base_Inference_in_Biomedical_Entity_Linking.pdf',
#  '2303.11032v1.DeID_GPT__Zero_shot_Medical_Text_De_Identification_by_GPT_4.pdf',
#  '2303.12892v1.A_Small_Scale_Switch_Transformer_and_NLP_based_Model_for_Clinical_Narratives_Classification.pdf',
#  '2303.12898v1.Towards_Understanding_the_Generalization_of_Medical_Text_to_SQL_Models_and_Datasets.pdf',
#  '2303.13314v1.Leveraging_Foundation_Models_for_Clinical_Text_Analysis.pdf',
#  '2303.13375v2.Capabilities_of_GPT_4_on_Medical_Challenge_Problems.pdf',
#  '2303.14070v5.ChatDoctor__A_Medical_Chat_Model_Fine_Tuned_on_a_Large_Language_Model_Meta_AI__LLaMA__Using_Medical_Domain_Knowledge.pdf',
#  '2303.14920v1.Adapting_Pretrained_Language_Models_for_Solving_Tabular_Prediction_Problems_in_the_Electronic_Health_Record.pdf',
#  '2303.15846v1.Soft_prompt_tuning_to_predict_lung_cancer_using_primary_care_free_text_Dutch_medical_notes.pdf',
#  '2303.16756v1.LLM_for_Patient_Trial_Matching__Privacy_Aware_Data_Augmentation_Towards_Better_Performance_and_Generalizability.pdf',
#  '2303.17408v1.Medical_Intervention_Duration_Estimation_Using_Language_enhanced_Transformer_Encoder_with_Medical_Prompts.pdf',
#  '2303.17807v1.Exploring_the_Potential_of_Large_Language_models_in_Traditional_Korean_Medicine__A_Foundation_Model_Approach_to_Culturally_Adapted_Healthcare.pdf',
#  '2303.18027v2.Evaluating_GPT_4_and_ChatGPT_on_Japanese_Medical_Licensing_Examinations.pdf',
#  '2304.00958v2.DrBERT__A_Robust_Pre_trained_Model_in_French_for_Biomedical_and_Clinical_domains.pdf',
#  '2304.01097v2.DoctorGLM__Fine_tuning_your_Chinese_Doctor_is_not_a_Herculean_Task.pdf',
#  '2304.01974v1.Dialogue_Contextualized_Re_ranking_for_Medical_History_Taking.pdf',
#  '2304.02496v1.Evaluation_of_ChatGPT_Family_of_Models_for_Biomedical_Reasoning_and_Classification.pdf',
#  '2304.02768v1.Application_of_Transformers_based_methods_in_Electronic_Medical_Records__A_Systematic_Literature_Review.pdf',
#  '2304.02886v1.Automatic_ICD_10_Code_Association__A_Challenging_Task_on_French_Clinical_Texts.pdf',
#  '2304.04280v1.FrenchMedMCQA__A_French_Multiple_Choice_Question_Answering_Dataset_for_Medical_domain.pdf',
#  '2304.04590v1.LADER__Log_Augmented_DEnse_Retrieval_for_Biomedical_Literature_Search.pdf',
#  '2304.05268v1.An_Entity_based_Claim_Extraction_Pipeline_for_Real_world_Biomedical_Fact_checking.pdf',
#  '2304.05368v2.Are_Large_Language_Models_Ready_for_Healthcare__A_Comparative_Study_on_Clinical_Language_Understanding.pdf',
#  '2304.05929v1.ReDWINE__A_Clinical_Datamart_with_Text_Analytical_Capabilities_to_Facilitate_Rehabilitation_Research.pdf',
#  '2304.05973v1.HiPrompt__Few_Shot_Biomedical_Knowledge_Fusion_via_Hierarchy_Oriented_Prompting.pdf',
#  '2304.06975v1.HuaTuo__Tuning_LLaMA_Model_with_Chinese_Medical_Knowledge.pdf',
#  '2304.07437v1.Medical_Question_Summarization_with_Entity_driven_Contrastive_Learning.pdf',
#  '2304.08247v1.MedAlpaca____An_Open_Source_Collection_of_Medical_Conversational_AI_Models_and_Training_Data.pdf',
#  '2304.08763v2.A_Survey_for_Biomedical_Text_Summarization__From_Pre_trained_to_Large_Language_Models.pdf',
#  '2304.08999v1.A_Biomedical_Entity_Extraction_Pipeline_for_Oncology_Health_Records_in_Portuguese.pdf',
#  '2304.09667v3.GeneGPT__Augmenting_Large_Language_Models_with_Domain_Tools_for_Improved_Access_to_Biomedical_Information.pdf',
#  '2304.10996v1.BERT_Based_Clinical_Knowledge_Extraction_for_Biomedical_Knowledge_Graph_Construction_and_Analysis.pdf',
#  '2304.11567v1.Differentiate_ChatGPT_generated_and_Human_written_Medical_Texts.pdf',
#  '2304.13875v1.MasonNLP__at_SemEval_2023_Task_8__Extracting_Medical_Questions__Experiences_and_Claims_from_Social_Media_using_Knowledge_Augmented_Pre_trained_Language_Models.pdf',
#  '2304.14405v1.ViMQ__A_Vietnamese_Medical_Question_Dataset_for_Healthcare_Dialogue_System_Development.pdf',
#  '2305.01146v2.RadAdapt__Radiology_Report_Summarization_via_Lightweight_Domain_Adaptation_of_Large_Language_Models.pdf',
#  '2305.03169v2.Sensitive_Data_Detection_with_High_Throughput_Machine_Learning_Models_in_Electrical_Health_Records.pdf',
#  '2305.03598v1.NLI4CT__Multi_Evidence_Natural_Language_Inference_for_Clinical_Trial_Reports.pdf',
#  '2305.03642v3.Jointly_Extracting_Interventions__Outcomes__and_Findings_from_RCT_Reports_with_LLMs.pdf',
#  '2305.03715v1.Large_Language_Models_in_Ambulatory_Devices_for_Home_Health_Diagnostics__A_case_study_of_Sickle_Cell_Anemia_Management.pdf',
#  '2305.04561v2.Boosting_Radiology_Report_Generation_by_Infusing_Comparison_Prior.pdf',
#  '2305.04905v1.What_Do_Patients_Say_About_Their_Disease_Symptoms__Deep_Multilabel_Text_Classification_With_Human_in_the_Loop_Curation_for_Automatic_Labeling_of_Patient_Self_Reports_of_Problems.pdf',
#  '2305.05640v2.Representation_Learning_for_Person_or_Entity_centric_Knowledge_Graphs__An_Application_in_Healthcare.pdf',
#  '2305.06416v1.A_Method_to_Automate_the_Discharge_Summary_Hospital_Course_for_Neurology_Patients.pdf',
#  '2305.06801v1.Detecting_Idiomatic_Multiword_Expressions_in_Clinical_Terminology_using_Definition_Based_Representation_Learning.pdf',
#  '2305.07340v1.MedGPTEval__A_Dataset_and_Benchmark_to_Evaluate_Responses_of_Large_Language_Models_in_Medicine.pdf',
#  '2305.07468v1.BactInt__A_domain_driven_transfer_learning_approach_and_a_corpus_for_extracting_inter_bacterial_interactions_from_biomedical_text.pdf',
#  '2305.07804v3.Improving_Small_Language_Models_on_PubMedQA_via_Generative_Data_Augmentation.pdf',
#  '2305.08787v1.Comparing_Variation_in_Tokenizer_Outputs_Using_a_Series_of_Problematic_and_Challenging_Biomedical_Sentences.pdf',
#  '2305.09617v1.Towards_Expert_Level_Medical_Question_Answering_with_Large_Language_Models.pdf',
#  '2305.09756v1.Clinical_Note_Owns_its_Hierarchy__Multi_Level_Hypergraph_Neural_Networks_for_Patient_Level_Representation_Learning.pdf',
#  '2305.10647v1.BioAug__Conditional_Generation_based_Data_Augmentation_for_Low_Resource_Biomedical_NER.pdf',
#  '2305.11366v1.AutoTrial__Prompting_Language_Models_for_Clinical_Trial_Design.pdf',
#  '2305.13395v1.BioDEX__Large_Scale_Biomedical_Adverse_Drug_Event_Extraction_for_Real_World_Pharmacovigilance.pdf',
#  '2305.17100v1.BiomedGPT__A_Unified_and_Generalist_Biomedical_Generative_Pre_trained_Transformer_for_Vision__Language__and_Multimodal_Tasks.pdf',
#  '2305.17364v1.An_Investigation_of_Evaluation_Metrics_for_Automated_Medical_Note_Generation.pdf',
#  '2305.18109v1.Medical_Dialogue_Generation_via_Dual_Flow_Modeling.pdf',
#  '2305.18152v1.Extrinsic_Factors_Affecting_the_Accuracy_of_Biomedical_NER.pdf',
#  '2305.19120v1.Comparing_and_combining_some_popular_NER_approaches_on_Biomedical_tasks.pdf',
#  '2305.19894v1.Med_UniC__Unifying_Cross_Lingual_Medical_Vision_Language_Pre_Training_by_Diminishing_Bias.pdf',
#  '2306.00005v1.A_Two_Stage_Decoder_for_Efficient_ICD_Coding.pdf',
#  '2306.00024v1.Self_Verification_Improves_Few_Shot_Clinical_Information_Extraction.pdf',
#  '2306.00665v1.Automatic_Glossary_of_Clinical_Terminology__a_Large_Scale_Dictionary_of_Biomedical_Definitions_Generated_from_Ontological_Knowledge.pdf',
#  '2306.00890v1.LLaVA_Med__Training_a_Large_Language_and_Vision_Assistant_for_Biomedicine_in_One_Day.pdf',
#  '2306.01931v1.Exploring_semantic_information_in_disease__Simple_Data_Augmentation_Techniques_for_Chinese_Disease_Normalization.pdf',
#  '2306.02022v1.ACI_BENCH__a_Novel_Ambient_Clinical_Intelligence_Dataset_for_Benchmarking_Automatic_Visit_Note_Generation.pdf',
#  '2306.02492v1.RadLing__Towards_Efficient_Radiology_Report_Understanding.pdf',
#  '2306.02754v1.PULSAR__Pre_training_with_Extracted_Healthcare_Terms_for_Summarising_Patients__Problems_and_Data_Augmentation_with_Black_box_Large_Language_Models.pdf',
#  '2306.03264v1.shs_nlp_at_RadSum23__Domain_Adaptive_Pre_training_of_Instruction_tuned_LLMs_for_Radiology_Report_Impression_Generation.pdf',
#  '2306.03652v1.Injecting_knowledge_into_language_generation__a_case_study_in_auto_charting_after_visit_care_instructions_from_medical_dialogue.pdf',
#  '2306.04384v1.Multilingual_Clinical_NER__Translation_or_Cross_lingual_Transfer_.pdf',
#  '2306.04802v1.A_Survey_on_Knowledge_Graphs_for_Healthcare__Resources__Applications__and_Promises.pdf',
#  '2306.04820v1.Good_Data__Large_Data__or_No_Data__Comparing_Three_Approaches_in_Developing_Research_Aspect_Classifiers_for_Biomedical_Papers.pdf',
#  '2306.05270v1.Overview_of_the_Problem_List_Summarization__ProbSum__2023_Shared_Task_on_Summarizing_Patients__Active_Diagnoses_and_Problems_from_Electronic_Health_Record_Progress_Notes.pdf',
#  '2306.05276v1.Extensive_Evaluation_of_Transformer_based_Architectures_for_Adverse_Drug_Events_Extraction.pdf',
#  '2306.05642v1.Customizing_General_Purpose_Foundation_Models_for_Medical_Report_Generation.pdf',
#  '2306.07297v1.Medical_Data_Augmentation_via_ChatGPT__A_Case_Study_on_Medication_Identification_and_Medication_Event_Classification.pdf',
#  '2306.07373v1.EriBERTa__A_Bilingual_Pre_Trained_Language_Model_for_Clinical_Natural_Language_Processing.pdf',
#  '2306.08018v1.Mol_Instructions__A_Large_Scale_Biomolecular_Instruction_Dataset_for_Large_Language_Models.pdf',
#  '2306.08403v1.Building_a_Corpus_for_Biomedical_Relation_Extraction_of_Species_Mentions.pdf',
#  '2306.08666v1.Radiology_GPT__A_Large_Language_Model_for_Radiology.pdf',
#  '2306.09968v1.ClinicalGPT__Large_Language_Models_Finetuned_with_Diverse_Medical_Data_and_Comprehensive_Evaluation.pdf',
#  '2306.10765v1.Path_to_Medical_AGI__Unify_Domain_specific_Medical_LLMs_with_the_Lowest_Cost.pdf',
#  '2306.11189v1.BioREx__Improving_Biomedical_Relation_Extraction_by_Leveraging_Heterogeneous_Datasets.pdf',
#  '2306.11345v1.KiUT__Knowledge_injected_U_Transformer_for_Radiology_Report_Generation.pdf',
#  '2306.14704v1.Ontology_Enrichment_from_Texts__A_Biomedical_Dataset_for_Concept_Discovery_and_Placement.pdf',
#  '2306.15550v1.CamemBERT_bio__a_Tasty_French_Language_Model_Better_for_your_Health.pdf',
#  '2306.15736v2.DMNER__Biomedical_Entity_Recognition_by_Detection_and_Matching.pdf',
#  '2306.16931v1.UMASS_BioNLP_at_MEDIQA_Chat_2023__Can_LLMs_generate_high_quality_synthetic_note_oriented_doctor_patient_conversations_.pdf',
#  '2306.17180v1.Replace_and_Report__NLP_Assisted_Radiology_Report_Generation.pdf',
#  '2306.17257v1.Prediction_of_COVID_19_Patients__Emergency_Room_Revisit_using_Multi_Source_Transfer_Learning.pdf',
#  '2306.17384v1.SummQA_at_MEDIQA_Chat_2023_In_Context_Learning_with_GPT_4_for_Medical_Summarization.pdf',
#  '2306.17649v3.Biomedical_Language_Models_are_Robust_to_Sub_optimal_Tokenization.pdf',
#  '2307.00186v1.How_far_is_Language_Model_from_100__Few_shot_Named_Entity_Recognition_in_Medical_Domain.pdf',
#  '2307.00266v1.Hierarchical_Pretraining_for_Biomedical_Term_Embeddings.pdf',
#  '2307.00381v1.Effective_Matching_of_Patients_to_Clinical_Trials_using_Entity_Extraction_and_Neural_Re_ranking.pdf',
#  '2307.00589v1.BioCPT__Contrastive_Pre_trained_Transformers_with_Large_scale_PubMed_Search_Logs_for_Zero_shot_Biomedical_Information_Retrieval.pdf',
#  '2307.01137v1.Exploring_the_In_context_Learning_Ability_of_Large_Language_Model_for_Biomedical_Concept_Linking.pdf',
#  '2307.03859v1.MDACE__MIMIC_Documents_Annotated_with_Code_Evidence.pdf',
#  '2307.05131v1.Overview_of_BioASQ_2023__The_eleventh_BioASQ_challenge_on_Large_Scale_Biomedical_Semantic_Indexing_and_Question_Answering.pdf',
#  '2307.05560v1.Automatic_Coding_at_Scale__Design_and_Deployment_of_a_Nationwide_System_for_Normalizing_Referrals_in_the_Chilean_Public_Healthcare_System.pdf',
#  '2307.06439v1.Distilling_Large_Language_Models_for_Biomedical_Knowledge_Extraction__A_Case_Study_on_Adverse_Drug_Events.pdf',
#  '2307.07051v1.Making_the_Most_Out_of_the_Limited_Context_Length__Predictive_Power_Varies_with_Clinical_Note_Type_and_Note_Section.pdf',
#  '2307.07362v1.A_scoping_review_on_multimodal_deep_learning_in_biomedical_images_and_texts.pdf',
#  '2307.07513v1.An_empirical_study_of_using_radiology_reports_and_images_to_improve_ICU_mortality_prediction.pdf',
#  '2307.08152v1.The_Potential_and_Pitfalls_of_using_a_Large_Language_Model_such_as_ChatGPT_or_GPT_4_as_a_Clinical_Assistant.pdf',
#  '2307.08290v1.CoAD__Automatic_Diagnosis_through_Symptom_and_Disease_Collaborative_Generation.pdf']

# %%
def fix_document_name(document, pdf_name):
    #some documents have really long names
    #if document.metadata['title'].strip() == '':
    document.metadata['title'] = pdf_name

# %%
def get_pdf_content(document):
    content = ""
    for page in document:
        content += page.get_text()
    return content

#print(get_pdf_content(document))

# %%
def is_pymupdf_extractable(document,content):
    print(document.metadata['creator'])
    acceptable_creator = ['Springer','Pages', 'LaTeX with hyperref', 
                          'LaTeX with acmart 2020/04/30 v1.71 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX',
                          'LaTeX with acmart 2022/02/19 v1.83 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX']
    words_threshold = 20
    #if (document.metadata['creator'] in acceptable_creator) and (len(content) > words_threshold):
    if (len(content) > words_threshold):
        return True
    else:
        print(document.metadata['title']+" "+document.metadata['creator'])
        return False
    
def write_json_file(filename, content):
    pathlib.Path(JSON_BASE+filename).write_bytes(content.encode('utf-8').strip())

def save_content(document,content):
    document_dict = dict()
    filename = document.metadata['title']+'.json'
    document_dict['title'] = document.metadata['title']
    document_dict['text'] = content
    document_dict['extraction_date'] = str(datetime.utcnow())
    document_dict['num_pages'] = document.page_count
    json_object = json.dumps(document_dict) 
    write_json_file(filename,json_object)

# %%
for pdf_name in pdf_files:
    with fitz.open(join(PDF_BASE, pdf_name)) as document:
        content = get_pdf_content(document)
        if is_pymupdf_extractable(document,content):
            fix_document_name(document, pdf_name)
            save_content(document,content)
# Out:
# Certified by IEEE PDFeXpress at September 29, 2022 07:16:23
# LaTeX with hyperref
# LaTeX with acmart 2021/08/29 v1.79 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# Hwp 2018 10.0.0.11808
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# TeX
# Microsoft® Word LTSC
# LaTeX with hyperref
# LaTeX with hyperref
# Word
# Microsoft® Word for Microsoft 365
# Word
# LaTeX with hyperref
# LaTeX with acmart 2020/09/13 v1.73 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# Word
# LaTeX with hyperref
#
# LaTeX with hyperref
#
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with acmart 2020/09/13 v1.73 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with acmart 2022/04/09 v1.84 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# Microsoft® Word 2016
# LaTeX with hyperref
# LaTeX with hyperref
# Microsoft Word
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# Microsoft® Word 适用于 Microsoft 365
# Microsoft Word
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# TeX
# Word
# Word
# LaTeX with acmart 2022/08/27 v1.87 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# Microsoft® Word for Microsoft 365
# LaTeX with hyperref
# wkhtmltopdf 0.12.4
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# Microsoft® Word Microsoft 365용
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
#
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with acmart 2023/03/30 v1.90 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# Word
# LaTeX with acmart 2020/04/30 v1.71 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX3; cas-sc.cls; hyperref.sty
# LaTeX with hyperref
# LaTeX with acmart 2023/03/30 v1.90 Typesetting articles for the Association for Computing Machinery and hyperref 2023-04-22 v7.00x Hypertext links for LaTeX
# LaTeX with acmart 2018/07/16 v1.54 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# Acrobat PDFMaker 20 for Word
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with acmart 2022/10/24 v1.88 Typesetting articles for the Association for Computing Machinery and hyperref 2020-05-15 v7.00e Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with acmart 2023/03/30 v1.90 Typesetting articles for the Association for Computing Machinery and hyperref 2023-04-22 v7.00x Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
#
# LaTeX with hyperref
# LaTeX with acmart 2022/10/24 v1.88 Typesetting articles for the Association for Computing Machinery and hyperref 2023-04-22 v7.00x Hypertext links for LaTeX
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# Word
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
# LaTeX with hyperref
#
# LaTeX with hyperref
